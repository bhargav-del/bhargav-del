# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargav-del/bhargav-del/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import shutil

# Path to the folder you want to zip
folder_path = '/content/Downloaded_Songs'

# Path to save the zipped file
output_path = '/content/gane.zip'

# Zipping the folder
shutil.make_archive(output_path.replace('.zip', ''), 'zip', folder_path)

print(f'Folder zipped successfully! Saved as {output_path}')
# Out:
# Folder zipped successfully! Saved as /content/gane.zip
